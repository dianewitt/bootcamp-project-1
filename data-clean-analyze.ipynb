# %% [markdown]
# #### Import Dependencies

# %%
import os
import csv
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import linregress
import scipy.stats as st
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import and Cleanup of COVID Data (from The COVID Tracking Project)

# %%
# Step 1: Reference to csv data files
covid_path = "Resources/Data/COVID_Tracking_By_State_Thru_2020_10_09.csv"

# %%
# Step 2: Import csv files and create data frame, print headers to terminal
covid_df = pd.read_csv(covid_path)
covid_df.head()
# Out:
#         date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  10/9/2020    AK                A    60.0            60.0              0
# 1  10/9/2020    AL                A  2653.0          2496.0             16
# 2  10/9/2020    AR               A+  1503.0          1359.0              0
# 3  10/9/2020    AS                D     0.0             NaN              0
# 4  10/9/2020    AZ               A+  5746.0          5460.0              3
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN           NaN                     NaN                   51.0
# 1          157.0       17989.0                 17989.0                  816.0
# 2          144.0        5805.0                  5805.0                  546.0
# 3            NaN           NaN                     NaN                    NaN
# 4          286.0       20199.0                 20199.0                  706.0
#
#    ...  totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# 0  ...          493070.0                      1899                 NaN
# 1  ...         1196452.0                     11742                 NaN
# 2  ...         1111526.0                         0                 NaN
# 3  ...            1616.0                         0                 NaN
# 4  ...         1543445.0                     12350            300333.0
#
#    totalTestsAntigen  totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# 0                NaN                       NaN                      NaN
# 1                NaN                   59957.0                      NaN
# 2            21856.0                       NaN                  25538.0
# 3                NaN                       NaN                      NaN
# 4                NaN                       NaN                      NaN
#
#    totalTestsPeopleViral  totalTestsPeopleViralIncrease  totalTestsViral  \
# 0                    NaN                              0         493070.0
# 1                    NaN                              0        1196452.0
# 2                    NaN                              0        1111526.0
# 3                    NaN                              0           1616.0
# 4              1543445.0                          12350              NaN
#
#    totalTestsViralIncrease
# 0                     1899
# 1                    11742
# 2                        0
# 3                        0
# 4                        0
#
# [5 rows x 43 columns]

# %%
# Step 3: Reset data frame index and include only columns needed for merging and analysis
covid_df = covid_df[[
    'state','date','positive','totalTestResults']]
covid_df.head()
# Out:
#   state       date  positive  totalTestResults
# 0    AK  10/9/2020   10176.0          493070.0
# 1    AL  10/9/2020  163465.0         1196452.0
# 2    AR  10/9/2020   90145.0         1111526.0
# 3    AS  10/9/2020       0.0            1616.0
# 4    AZ  10/9/2020  224084.0         1543445.0

# %%
# Step 4: Split date by month, day and year
month = []
day = []
year = []

for column in covid_df["date"]:
    splitdate = column.split('/')
    month.append(splitdate[0])
    day.append(splitdate[1])
    year.append(splitdate[2])

covid_df["Month"] = month
covid_df["Day"] = day
covid_df["Year"] = year
covid_df.head()
# Out:
#   state       date  positive  totalTestResults Month Day  Year
# 0    AK  10/9/2020   10176.0          493070.0    10   9  2020
# 1    AL  10/9/2020  163465.0         1196452.0    10   9  2020
# 2    AR  10/9/2020   90145.0         1111526.0    10   9  2020
# 3    AS  10/9/2020       0.0            1616.0    10   9  2020
# 4    AZ  10/9/2020  224084.0         1543445.0    10   9  2020

# %%
# Step 5: Rename columns for readability
covid_df = covid_df.rename(columns={
    'state':'State',
    'positive':'Positive COVID Tests' ,
    'totalTestResults':'Total COVID Tests'
})
covid_df.head()
# Out:
#   State       date  Positive COVID Tests  Total COVID Tests Month Day  Year
# 0    AK  10/9/2020               10176.0           493070.0    10   9  2020
# 1    AL  10/9/2020              163465.0          1196452.0    10   9  2020
# 2    AR  10/9/2020               90145.0          1111526.0    10   9  2020
# 3    AS  10/9/2020                   0.0             1616.0    10   9  2020
# 4    AZ  10/9/2020              224084.0          1543445.0    10   9  2020

# %%
# Step 6: Add calculations as new columns
covid_df["COVID Positivity Rate"] = (covid_df["Positive COVID Tests"] / covid_df["Total COVID Tests"]*100)
covid_df.head()
# Out:
#   State       date  Positive COVID Tests  Total COVID Tests Month Day  Year  \
# 0    AK  10/9/2020               10176.0           493070.0    10   9  2020
# 1    AL  10/9/2020              163465.0          1196452.0    10   9  2020
# 2    AR  10/9/2020               90145.0          1111526.0    10   9  2020
# 3    AS  10/9/2020                   0.0             1616.0    10   9  2020
# 4    AZ  10/9/2020              224084.0          1543445.0    10   9  2020
#
#    COVID Positivity Rate
# 0               2.063804
# 1              13.662479
# 2               8.110022
# 3               0.000000
# 4              14.518431

# %%
# Step 7: convert data frame columns by type (as needed)
# How to convert a Pandas DataFrame column from object to int in Python
# https://www.kite.com/python/answers/how-to-convert-a-pandas-dataframe-column-from-object-to-int-in-python
covid_df["Month"] = covid_df["Month"].astype(str).astype(int)
covid_df["Year"] = covid_df["Year"].astype(str).astype(int)
covid_df.head()
# Out:
#   State       date  Positive COVID Tests  Total COVID Tests  Month Day  Year  \
# 0    AK  10/9/2020               10176.0           493070.0     10   9  2020
# 1    AL  10/9/2020              163465.0          1196452.0     10   9  2020
# 2    AR  10/9/2020               90145.0          1111526.0     10   9  2020
# 3    AS  10/9/2020                   0.0             1616.0     10   9  2020
# 4    AZ  10/9/2020              224084.0          1543445.0     10   9  2020
#
#    COVID Positivity Rate
# 0               2.063804
# 1              13.662479
# 2               8.110022
# 3               0.000000
# 4              14.518431

# %%
# Step 8: Replace values for Month (number) with names for readability
covid_df['Month'] = covid_df['Month'].replace({
    1:"01 Jan",
    2:"02 Feb",
    3:"03 Mar",
    4:"04 Apr",
    5:"05 May",
    6:"06 Jun",
    7:"07 Jul",
    8:"08 Aug",
    9:"09 Sep",
    10:"10 Oct",
    11:"11 Nov",
    12:"12 Dec"
})
covid_df.head()
# Out:
#   State       date  Positive COVID Tests  Total COVID Tests   Month Day  Year  \
# 0    AK  10/9/2020               10176.0           493070.0  10 Oct   9  2020
# 1    AL  10/9/2020              163465.0          1196452.0  10 Oct   9  2020
# 2    AR  10/9/2020               90145.0          1111526.0  10 Oct   9  2020
# 3    AS  10/9/2020                   0.0             1616.0  10 Oct   9  2020
# 4    AZ  10/9/2020              224084.0          1543445.0  10 Oct   9  2020
#
#    COVID Positivity Rate
# 0               2.063804
# 1              13.662479
# 2               8.110022
# 3               0.000000
# 4              14.518431

# %%
# Step 9: Replace 'State' abbreviation with with names for readability
covid_df['State'] = covid_df['State'].replace({
    'AK':'Alaska','AR':'Arkansas','CO':'Colorado','CT':'Connecticut',
    'FL':'Florida','IL':'Illinois','KS':'Kansas','KY':'Kentucky',
    'LA':'Louisiana','MA':'Massachusetts','MO':'Missouri',
    'ND':'North Dakota','OR':'Oregon','TX':'Texas','VA':'Virginia',
    'WI':'Wisconsin','WA':'Washington','NJ':'New Jersey','MI':'Michigan',
    'RI':'Rhode Island','AZ':'Arizona','HI':'Hawaii','NC':'North Carolina',
    'CA':'California','GA':'Georgia','SC':'South Carolina','NY':'New York',
    'NH':'New Hampshire','MD':'Maryland','NV':'Nevada','TN':'Tennesee',
    'NE':'Nebraska','OH':'Ohio','DC':'District of Columbia','IA':'Iowa',
    'NM':'New Mexico','WV':'West Virginia','IN':'Indiana',
    'MS':'Mississippi','MN':'Minnesota','PA':'Pennsylvania','VT':'Vermont',
    'DE':'Delaware','MT':'Montana','AL':'Alabama','ME':'Maine',
    'WY':'Wyoming','UT':'Utah','ID':'Idaho','OK':'Oklahoma',
    'SD':'South Dakota','VI':'Virgin Islands','AS':'American Samoa',
    'GU':'Guam','MP':'Northern Mariana Islands','PR':'Puerto Rico'    
})
covid_df.head()
# Out:
#             State       date  Positive COVID Tests  Total COVID Tests   Month  \
# 0          Alaska  10/9/2020               10176.0           493070.0  10 Oct
# 1         Alabama  10/9/2020              163465.0          1196452.0  10 Oct
# 2        Arkansas  10/9/2020               90145.0          1111526.0  10 Oct
# 3  American Samoa  10/9/2020                   0.0             1616.0  10 Oct
# 4         Arizona  10/9/2020              224084.0          1543445.0  10 Oct
#
#   Day  Year  COVID Positivity Rate
# 0   9  2020               2.063804
# 1   9  2020              13.662479
# 2   9  2020               8.110022
# 3   9  2020               0.000000
# 4   9  2020              14.518431

# %%
# Step 10: Create a .csv file for the cleaned data frame
covid_df.to_csv(r'Resources\Data\cleaned_covid_data.csv', index=False)

# %% [markdown]
# ______________

# %% [markdown]
# #### Cleanup of Alcohol Consumption Data (from NIH)

# %%
# Step 1: Reference to csv data files
alcohol_path = "Resources/Data/NIH_Alcohol_Sales_Thru_Jun2020.csv"

# %%
# Step 2: Import csv files and create data frame, print headers to terminal
alcohol_df = pd.read_csv("Resources/Data/NIH_Alcohol_Sales_Thru_Jun2020.csv")
alcohol_df.head()
# Out:
#    Year  Month  FIPS  Beverage  Gallons  Ethanol  Population  PerCapita  \
# 0  2017      1     2         1   103645    42598      593378     0.0718
# 1  2017      1     5         1   402885   165586     2455022     0.0674
# 2  2017      1     8         1   733857   301615     4634346     0.0651
# 3  2017      1     9         1   412100   169373     3015481     0.0562
# 4  2017      1    12         1  2770686  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %%
# Step 3: Reset data frame index and include only columns needed for merging and analysis
alcohol_df = alcohol_df[[
    'FIPS','Year','Month','Beverage','Ethanol',
    'Population','PerCapita','PerCapita3yr','PctChange']]
alcohol_df.head()
# Out:
#    FIPS  Year  Month  Beverage  Ethanol  Population  PerCapita  PerCapita3yr  \
# 0     2  2017      1         1    42598      593378     0.0718           NaN
# 1     5  2017      1         1   165586     2455022     0.0674           NaN
# 2     8  2017      1         1   301615     4634346     0.0651           NaN
# 3     9  2017      1         1   169373     3015481     0.0562           NaN
# 4    12  2017      1         1  1138752    17722275     0.0643           NaN
#
#    PctChange
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Step 4: Rename columns for readability
alcohol_df = alcohol_df.rename(columns={
    'FIPS':'State',
})
alcohol_df.head()
# Out:
#    State  Year  Month  Beverage  Ethanol  Population  PerCapita  PerCapita3yr  \
# 0      2  2017      1         1    42598      593378     0.0718           NaN
# 1      5  2017      1         1   165586     2455022     0.0674           NaN
# 2      8  2017      1         1   301615     4634346     0.0651           NaN
# 3      9  2017      1         1   169373     3015481     0.0562           NaN
# 4     12  2017      1         1  1138752    17722275     0.0643           NaN
#
#    PctChange
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Step 5: Replace values for Beverage (code) with names for readability
alcohol_df['Beverage'] = alcohol_df['Beverage'].replace({
    1:'Spirits',
    2:'Wine',
    3:'Beer'
})
alcohol_df.head()
# Out:
#    State  Year  Month Beverage  Ethanol  Population  PerCapita  PerCapita3yr  \
# 0      2  2017      1  Spirits    42598      593378     0.0718           NaN
# 1      5  2017      1  Spirits   165586     2455022     0.0674           NaN
# 2      8  2017      1  Spirits   301615     4634346     0.0651           NaN
# 3      9  2017      1  Spirits   169373     3015481     0.0562           NaN
# 4     12  2017      1  Spirits  1138752    17722275     0.0643           NaN
#
#    PctChange
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Step 6: Replace values for State (code) with names for readability
alcohol_df['State'] = alcohol_df['State'].replace({
    2:'Alaska',5:'Arkansas',8:'Colorado',9:'Connecticut',12:'Florida',
    17:'Illinois',20:'Kansas',21:'Kentucky',22:'Louisiana',
    25:'Massachusetts',29:'Missouri',38:'North Dakota',41:'Oregon',
    48:'Texas',51:'Virginia',55:'Wisconsin'
})
alcohol_df.head()
# Out:
#          State  Year  Month Beverage  Ethanol  Population  PerCapita  \
# 0       Alaska  2017      1  Spirits    42598      593378     0.0718
# 1     Arkansas  2017      1  Spirits   165586     2455022     0.0674
# 2     Colorado  2017      1  Spirits   301615     4634346     0.0651
# 3  Connecticut  2017      1  Spirits   169373     3015481     0.0562
# 4      Florida  2017      1  Spirits  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %%
# Step 7: Replace values for Month (number) with names for readability
alcohol_df['Month'] = alcohol_df['Month'].replace({
    1:"01 Jan",
    2:"02 Feb",
    3:"03 Mar",
    4:"04 Apr",
    5:"05 May",
    6:"06 Jun",
    7:"07 Jul",
    8:"08 Aug",
    9:"09 Sep",
    10:"10 Oct",
    11:"11 Nov",
    12:"12 Dec"
})
alcohol_df.head()
# Out:
#          State  Year   Month Beverage  Ethanol  Population  PerCapita  \
# 0       Alaska  2017  01 Jan  Spirits    42598      593378     0.0718
# 1     Arkansas  2017  01 Jan  Spirits   165586     2455022     0.0674
# 2     Colorado  2017  01 Jan  Spirits   301615     4634346     0.0651
# 3  Connecticut  2017  01 Jan  Spirits   169373     3015481     0.0562
# 4      Florida  2017  01 Jan  Spirits  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %%
# Step 8: Add calculations as new columns
alcohol_df["PerCapita"] = (alcohol_df["PerCapita"])
alcohol_df.head()
# Out:
#          State  Year   Month Beverage  Ethanol  Population  PerCapita  \
# 0       Alaska  2017  01 Jan  Spirits    42598      593378     0.0718
# 1     Arkansas  2017  01 Jan  Spirits   165586     2455022     0.0674
# 2     Colorado  2017  01 Jan  Spirits   301615     4634346     0.0651
# 3  Connecticut  2017  01 Jan  Spirits   169373     3015481     0.0562
# 4      Florida  2017  01 Jan  Spirits  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %%
# Step 8: Add calculations as new columns
alcohol_df["PerCapita3yr"] = (alcohol_df["PerCapita3yr"])
alcohol_df.head()
# Out:
#          State  Year   Month Beverage  Ethanol  Population  PerCapita  \
# 0       Alaska  2017  01 Jan  Spirits    42598      593378     0.0718
# 1     Arkansas  2017  01 Jan  Spirits   165586     2455022     0.0674
# 2     Colorado  2017  01 Jan  Spirits   301615     4634346     0.0651
# 3  Connecticut  2017  01 Jan  Spirits   169373     3015481     0.0562
# 4      Florida  2017  01 Jan  Spirits  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN

# %%
# Step 9: Create a .csv file for the cleaned data frame
alcohol_df.to_csv(r'Resources\Data\cleaned_alcohol_data.csv', index=False)

# %% [markdown]
# ______________

# %% [markdown]
# #### Alcohol Consumption Data (NIH)

# %%
season_df = alcohol_df.groupby(['Year', 'Month']).agg({'PerCapita': ['mean']})
season_df.columns = ['PerCapita']
season_df.reset_index(inplace=True)
season_df.head()
# Out:
#    Year   Month  PerCapita
# 0  2017  01 Jan   0.057459
# 1  2017  02 Feb   0.056659
# 2  2017  03 Mar   0.066859
# 3  2017  04 Apr   0.066686
# 4  2017  05 May   0.071557

# %%
season_df["Year"].unique().tolist()
for y in season_df["Year"].unique().tolist():
    season_df[y] = season_df.loc[ season_df["Year"]== y ,'PerCapita']
    
plot_df =season_df.copy(deep=True)
plot_df = plot_df.drop(columns=["Year","PerCapita"]).set_index("Month")
plot_df = pd.DataFrame({ col: plot_df[col].dropna() for col in plot_df.columns})
plot_df = plot_df.apply (pd.to_numeric, errors='coerce')
plot_df = plot_df.dropna()
plot_df.head()
# Out:
#             2017      2018      2019      2020
# Month
# 01 Jan  0.057459  0.057291  0.061366  0.062484
# 02 Feb  0.056659  0.056209  0.055927  0.059198
# 03 Mar  0.066859  0.063961  0.063289  0.067464
# 04 Apr  0.066686  0.064827  0.068030  0.067205
# 05 May  0.071557  0.074345  0.073457  0.071232

# %%
plot_df.plot(figsize=(15,5))
plt.xlabel("Month")
plt.ylabel("Average Ethanol Gallons Per Capita")
plt.xticks(rotation=30, horizontalalignment="center")
plt.legend(loc='upper right', bbox_to_anchor=(1.12, 1))
plt.title("Figure 1: Average Ethanol Consumption by Month / Seasonality")
plt.savefig("Images/fig1.png")

# %%
plot_df.plot(kind='bar', figsize=(15,5), align="center")
plt.xlabel("Month")
plt.ylabel("Average Ethanol Gallons Per Capita")
plt.xticks(rotation=30, horizontalalignment="center")
plt.xticks(rotation=30, horizontalalignment="center")
plt.legend(loc='upper right', bbox_to_anchor=(1.12, 1))
plt.title("Figure 2: Average Ethanol Consumption by Month / Seasonality")
plt.savefig("Images/fig2.png")

# %%
groups = [[0.090188, 0.088401, 0.087805, 0.083765], 
          [0.080462, 0.081422, 0.084167, 0.084339], 
          [0.036707, 0.036455, 0.035961, 0.035041]]
group_legend = ['2017', '2018', '2019', '2020']
group_labels = ['Beer', 'Spirits', 'Wine']

bar2_df = pd.DataFrame(groups, index=group_labels).T
bar2_df.head()
# Out:
#        Beer   Spirits      Wine
# 0  0.090188  0.080462  0.036707
# 1  0.088401  0.081422  0.036455
# 2  0.087805  0.084167  0.035961
# 3  0.083765  0.084339  0.035041

# %%
bar2_df['Year'] = group_legend
bar2_df = bar2_df.set_index('Year')
bar2_df
# Out:
#           Beer   Spirits      Wine
# Year
# 2017  0.090188  0.080462  0.036707
# 2018  0.088401  0.081422  0.036455
# 2019  0.087805  0.084167  0.035961
# 2020  0.083765  0.084339  0.035041

# %%
bar2_df.plot(kind='bar', figsize=(15,5), align="center")
plt.title("Figure 3: Average Ethanol Consumption by Month / Seasonality")
plt.xlabel("Year")
plt.ylabel("Average Ethanol Gallons Per Capita")
plt.xticks(rotation=30, horizontalalignment="center")
plt.legend(loc='upper right', bbox_to_anchor=(1.12, 1))
plt.savefig("Images/fig3.png")

# %%
# 2.1
season_df = alcohol_df.groupby(['Year', 'Month']).agg({'PerCapita': ['sum']})
season_df.columns = ['PerCapita']
season_df.reset_index(inplace=True)
season_df.head()
# Out:
#    Year   Month  PerCapita
# 0  2017  01 Jan     2.5282
# 1  2017  02 Feb     2.4930
# 2  2017  03 Mar     2.9418
# 3  2017  04 Apr     2.9342
# 4  2017  05 May     3.1485

# %%
# 2.2
season_df["Year"].unique().tolist()
for y in season_df["Year"].unique().tolist():
    season_df[y] = season_df.loc[ season_df["Year"]== y ,'PerCapita']
    
plot_df =season_df.copy(deep=True)
plot_df = plot_df.drop(columns=["Year","PerCapita"]).set_index("Month")
plot_df = pd.DataFrame({ col: plot_df[col].dropna() for col in plot_df.columns})
plot_df = plot_df.apply (pd.to_numeric, errors='coerce')
plot_df = plot_df.dropna()
plot_df.head()
# Out:
#           2017    2018    2019    2020
# Month
# 01 Jan  2.5282  2.5208  2.7001  2.7493
# 02 Feb  2.4930  2.4732  2.4608  2.6047
# 03 Mar  2.9418  2.8143  2.7847  2.9684
# 04 Apr  2.9342  2.8524  2.9933  2.9570
# 05 May  3.1485  3.2712  3.2321  2.9205

# %%
plot_df.plot(figsize=(15,5))
plt.xlabel("Month")
plt.ylabel("Total Ethanol Gallons Per Capita")
plt.xticks(rotation=30, horizontalalignment="center")
plt.legend(loc='upper right', bbox_to_anchor=(1.12, 1))
plt.title("Figure 4: Total Ethanol Consumption by Month / Seasonality")
plt.savefig("Images/fig4.png")

# %%
plot_df.plot(kind='bar', figsize=(15,5), align="center")
plt.xlabel("Month")
plt.ylabel("Total Ethanol Gallons Per Capita")
plt.xticks(rotation=30, horizontalalignment="center")
plt.legend(loc='upper right', bbox_to_anchor=(1.12, 1))
plt.title("Figure 5: Total Ethanol Consumption by Month / Seasonality")
plt.savefig("Images/fig5.png")

# %% [markdown]
# __________________________

# %% [markdown]
# #### Merge The Two Data Frames

# %%
# Merge the cleaned data frames: covid_df and alcohol_df
merged_df = pd.merge(alcohol_df, covid_df, how="left", on=("State","Year","Month"))
merged_df.head()
# Out:
#          State  Year   Month Beverage  Ethanol  Population  PerCapita  \
# 0       Alaska  2017  01 Jan  Spirits    42598      593378     0.0718
# 1     Arkansas  2017  01 Jan  Spirits   165586     2455022     0.0674
# 2     Colorado  2017  01 Jan  Spirits   301615     4634346     0.0651
# 3  Connecticut  2017  01 Jan  Spirits   169373     3015481     0.0562
# 4      Florida  2017  01 Jan  Spirits  1138752    17722275     0.0643
#
#    PerCapita3yr  PctChange date  Positive COVID Tests  Total COVID Tests  Day  \
# 0           NaN        NaN  NaN                   NaN                NaN  NaN
# 1           NaN        NaN  NaN                   NaN                NaN  NaN
# 2           NaN        NaN  NaN                   NaN                NaN  NaN
# 3           NaN        NaN  NaN                   NaN                NaN  NaN
# 4           NaN        NaN  NaN                   NaN                NaN  NaN
#
#    COVID Positivity Rate
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
# create a csv with the merged, cleaned data
merged_df.to_csv(r'Resources\Data\covid_v_alcohol.csv', index=False)

# %% [markdown]
# __________________

# %% [markdown]
# #### Question #1:
# What, if any, non-Pandemic year alcohol consumption rate changes occur with a given year? (i.e. Seasonality)

# %% [markdown]
# #### Question #2:
# Did alcohol consumption change in 2020/Pandemic months from the prior year? (i.e. sum)

# %% [markdown]
# #### Question #3:
# How did COVID shutdowns and infections rates affect alcohol consumption – if at all?

# %% [markdown]
# #### Question #5:
# Did regions not affected by shutdowns see any significant changes in alcohol consumption?

# %% [markdown]
# #### Question #6:
# Were alcohol consumption rates associated with infection rates? Or vice versa.

# %% [markdown]
# #### Optional: Alcoholic Beverage Preference by Year
